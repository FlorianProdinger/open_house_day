# %% [markdown]
# # Test notebook on my raspberry pi
#
# ## setup
#
# run `nohup jupyter notebook &` on the raspy. The settings are saved on ~/.jupyter/jupyter_notebook_config.py.
#
# log into the interactive session on the client pc by using firefox and the adress "http://192.168.40.112:8888"
#
# navigate to the correct folder in order to load some of the modules I made.

# %%
## loading the pacakges
from read_sensor import read_data
from datetime import datetime as dt
import sys
import pickle
import os
import numpy
import pandas as pd

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ## Measuring data
#
# the code below loads all necessary modules. we can start measure some data.

# %%
# generate some data
data_ = read_data()
sample_name_ = "test"
time_ = dt.now().strftime("%Y%m%d_%H%M%S")

# %%
#measuring nothing
data = pd.DataFrame(data_).mean()
data
# Out:
# 0    107.00
# 1    812.48
# 2    807.94
# dtype: float64

# %%
data_water_tap_ = read_data()
print( data_water_tap_ )
df.to_csv('water_tap.csv', index=False, encoding='utf-8-sig')
pd.DataFrame(data_water_tap_).mean()
# Out:
# {0: [104, 104, 104, 104, 103, 104, 104, 104, 103, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 105, 104, 104, 104, 104, 104, 104, 101, 104, 104, 104, 104, 104, 104, 104], 1: [817, 817, 818, 817, 827, 818, 820, 818, 823, 817, 818, 819, 817, 817, 820, 818, 829, 818, 818, 818, 818, 816, 819, 820, 817, 819, 818, 817, 819, 819, 819, 818, 819, 818, 819, 817, 818, 819, 786, 786, 787, 782, 791, 785, 785, 782, 783, 787, 787, 787], 2: [820, 819, 818, 820, 821, 817, 822, 816, 822, 820, 817, 823, 820, 818, 822, 818, 823, 823, 818, 821, 823, 818, 817, 823, 818, 822, 818, 818, 823, 817, 822, 818, 822, 817, 822, 818, 817, 822, 766, 762, 763, 768, 767, 768, 768, 768, 767, 767, 766, 762]}
# 0    103.92
# 1    810.82
# 2    806.90
# dtype: float64

# %%
data_water_sm = read_data()
print( data_water_sm)
df.to_csv('water_sm.csv', index=False, encoding='utf-8-sig')
pd.DataFrame(data_water_sm).mean()
# Out:
# {0: [25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 24, 25, 25, 25, 25, 25], 1: [877, 876, 876, 926, 926, 926, 927, 926, 925, 926, 927, 925, 926, 925, 925, 925, 925, 925, 926, 925, 926, 926, 926, 927, 925, 927, 927, 926, 925, 926, 926, 926, 926, 927, 926, 926, 927, 925, 926, 926, 926, 926, 926, 927, 925, 925, 926, 926, 931, 925], 2: [889, 890, 890, 951, 952, 952, 951, 950, 951, 951, 951, 951, 951, 951, 950, 950, 950, 950, 951, 951, 949, 951, 951, 950, 950, 952, 951, 951, 951, 952, 951, 955, 951, 952, 952, 951, 951, 951, 952, 950, 952, 950, 951, 951, 950, 952, 951, 950, 952, 951]}
# 0     24.98
# 1    923.00
# 2    947.34
# dtype: float64

# %%
data_tea = read_data()
print( data_tea)
#df.to_csv('tea.csv', index=False, encoding='utf-8-sig')
pd.DataFrame(data
 372, 371, 370, 370, 370, 370, 371, 372, 371, 370, 370, 370, 372, 372, 371, 370, 370, 370, 370, 371, 372, 371, 370, 370, 370, 371, 372, 372, 371, 371, 370, 371, 372, 372, 371, 370, 371, 371, 371, 372],
 1: [776, 768, 787, 778, 785, 780, 778, 786, 779, 778, 786, 787, 779, 786, 786, 787, 786, 768, 786, 778, 786, 778, 786, 778, 787, 778, 787, 779, 778, 777, 785, 787, 787, 780, 780, 778, 783, 776, 778, 779, 786, 780, 778, 785, 779, 786, 787, 780, 779, 778], 
 2: [736, 741, 794, 788, 794, 788, 794, 786, 788, 793, 794, 788, 788, 794, 794, 794, 786, 799, 795, 788, 795, 794, 787, 787, 788, 794, 788, 788, 794, 793, 794, 795, 788, 788, 788, 794, 794, 788, 793, 788, 794, 788, 794, 794, 787, 794, 788, 788, 787, 787]}

df.to_csv('pre.csv', index=False, encoding='utf-8-sig')
#print( data_water_tap_ )
#pd.DataFrame(data_water_tap_).mean()

# %%
# Get a new data from the sensor

data_new = read_data()
print(data_new)
pd.DataFrame(data_new).mean()
# Out:
# {0: [616, 614, 616, 615, 614, 616, 614, 616, 614, 616, 614, 614, 616, 614, 615, 613, 616, 613, 617, 614, 614, 617, 614, 616, 615, 614, 615, 613, 617, 614, 616, 614, 614, 616, 614, 605, 613, 617, 614, 617, 614, 616, 615, 614, 616, 614, 617, 613, 616, 614], 1: [798, 792, 798, 792, 797, 799, 793, 792, 792, 791, 797, 797, 798, 800, 793, 796, 793, 797, 792, 798, 792, 798, 792, 799, 793, 792, 796, 799, 798, 794, 792, 792, 800, 798, 792, 798, 793, 797, 792, 793, 799, 798, 794, 799, 793, 792, 792, 798, 793, 792], 2: [800, 799, 794, 792, 800, 795, 793, 791, 792, 799, 800, 800, 800, 793, 791, 800, 792, 800, 792, 801, 792, 794, 799, 793, 792, 799, 799, 800, 793, 792, 791, 799, 799, 792, 792, 800, 792, 794, 799, 792, 799, 793, 799, 793, 791, 799, 799, 801, 793, 792]}
# 0    614.70
# 1    795.10
# 2    795.72
# dtype: float64

# %%
# Merge pre_data & new data to one dataframe

df_main = {
  time_ + "_" +"water_tap" : pd.DataFrame(data_water_tap_).mean() ,
  time_ + "_" +"water_sm" : pd.DataFrame(data_water_sm_).mean() ,
  time_ + "_" +"apple" : pd.DataFrame(data_apple_).mean() ,
  time_ + "_" +"milk" : pd.DataFrame(data_milk_).mean() ,
  time_ + "_" +"coffee" : pd.DataFrame(data_coffee_).mean(),
  time_ + "_" +"new_sample" : pd.DataFrame(data_new).mean()
}

df = pd.DataFrame( df_main )
df
# Out:
#    20250803_141027_water_tap  20250803_141027_water_sm  20250803_141027_apple  \
# 0                     370.74                    376.50                 378.14
# 1                     781.38                    779.62                 778.32
# 2                     788.82                    767.84                 752.64
#
#    20250803_141027_milk  20250803_141027_coffee  20250803_141027_new_sample
# 0                381.70                  383.96                      614.70
# 1                779.18                  781.96                      795.10
# 2                761.68                  783.44                      795.72

# %%
# Transpose the DataFrame
df_transposed = df.T
df_transposed.columns = [f'sensor_{i}' for i in range(df_transposed.shape[1])] # Rename columns for clarity
df_transposed
# Out:
#                             sensor_0  sensor_1  sensor_2
# 20250803_141027_water_tap     370.74    781.38    788.82
# 20250803_141027_water_sm      376.50    779.62    767.84
# 20250803_141027_apple         378.14    778.32    752.64
# 20250803_141027_milk          381.70    779.18    761.68
# 20250803_141027_coffee        383.96    781.96    783.44
# 20250803_141027_new_sample    614.70    795.10    795.72

# %%
# Perform PCA on the transposed DataFrame
# For demonstration, we'll reduce to 2 components for plotting
pca = PCA(n_components=2)
principal_components_transposed = pca.fit_transform(df_transposed)

# %%
# Create a DataFrame for the principal components
pca_df_transposed = pd.DataFrame(data=principal_components_transposed,
                                 columns=['Principal Component 1', 'Principal Component 2'],
                                index = df_transposed.index)

# Print the explained variance ratio
print("\nExplained variance ratio for each component (on transposed data):")
print(pca.explained_variance_ratio_)
# Out:
# Explained variance ratio for each component (on transposed data):
# [0.98087569 0.01912144]

# %%
pca_df_transposed
# Out:
#                             Principal Component 1  Principal Component 2
# 20250803_141027_water_tap              -45.171187              18.692407
# 20250803_141027_water_sm               -41.753485              -2.865576
# 20250803_141027_apple                  -41.793163             -18.207930
# 20250803_141027_milk                   -37.262534              -9.574080
# 20250803_141027_coffee                 -32.574361              11.970663
# 20250803_141027_new_sample             198.554730              -0.015484

# %%
# Plotting the PCA results

plt.figure(figsize=(8, 6))
plt.scatter(pca_df_transposed['Principal Component 1'], pca_df_transposed['Principal Component 2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Transposed DataFrame')
plt.grid(True)
plt.savefig('pca_transposed_plot.png')
print("PCA plot of transposed DataFrame saved as pca_transposed_plot.png")


# Add labels to each point
for i, label in enumerate(pca_df_transposed.index):
    plt.annotate(label,                 # The text label
                 (pca_df_transposed['Principal Component 1'][i], # X-coordinate
                  pca_df_transposed['Principal Component 2'][i]),# Y-coordinate
                 textcoords="offset points", # How to position the text
                 xytext=(5,5),             # Distance from the point (x,y)
                 ha='left',                # Horizontal alignment
                 va='bottom')              # Vertical alignment
# Out:
# PCA plot of transposed DataFrame saved as pca_transposed_plot.png
# /tmp/ipykernel_15713/1662187912.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   (pca_df_transposed['Principal Component 1'][i], # X-coordinate
# /tmp/ipykernel_15713/1662187912.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pca_df_transposed['Principal Component 2'][i]),# Y-coordinate

# %% [markdown]
# # ここから昔のやつ

# %%
data_water_sm_ = read_data()
print(data_water_sm_)
pd.DataFrame(data_water_sm_).mean()
# Out:
# {0: [376, 377, 377, 376, 376, 376, 375, 376, 377, 369, 378, 377, 377, 376, 376, 376, 377, 378, 378, 377, 377, 376, 376, 376, 376, 377, 378, 377, 376, 376, 376, 377, 378, 378, 376, 376, 376, 376, 378, 378, 376, 376, 376, 376, 377, 378, 378, 377, 376, 376], 1: [776, 776, 776, 777, 772, 772, 770, 769, 768, 793, 776, 773, 771, 777, 775, 772, 776, 776, 776, 777, 777, 778, 778, 778, 785, 786, 786, 787, 779, 779, 785, 787, 783, 787, 779, 786, 779, 785, 787, 778, 786, 786, 787, 787, 787, 779, 778, 778, 786, 780], 2: [742, 734, 734, 735, 742, 742, 741, 741, 741, 747, 735, 735, 741, 735, 735, 741, 742, 734, 734, 735, 735, 735, 795, 794, 794, 794, 788, 788, 788, 787, 794, 788, 797, 794, 787, 795, 788, 794, 787, 793, 794, 794, 795, 788, 788, 788, 787, 794, 795, 788]}
# 0    376.50
# 1    779.62
# 2    767.84
# dtype: float64

# %%
data_apple_ = read_data()
print( data_apple_ )
pd.DataFrame(data_apple_).mean()
# Out:
# {0: [378, 377, 378, 378, 379, 379, 378, 378, 378, 378, 379, 379, 378, 378, 378, 378, 379, 379, 380, 378, 378, 378, 378, 378, 379, 379, 373, 379, 378, 378, 377, 378, 379, 380, 378, 378, 378, 378, 379, 379, 375, 379, 378, 378, 378, 379, 379, 379, 373, 380], 1: [787, 786, 779, 778, 785, 787, 787, 780, 779, 778, 787, 786, 787, 778, 777, 777, 777, 777, 772, 777, 777, 776, 777, 777, 777, 776, 778, 774, 777, 779, 776, 777, 778, 775, 778, 778, 777, 776, 775, 776, 778, 774, 776, 778, 776, 775, 773, 770, 783, 778], 2: [789, 795, 788, 793, 776, 788, 788, 788, 788, 794, 793, 794, 788, 788, 735, 735, 734, 734, 741, 735, 741, 741, 741, 734, 735, 741, 741, 740, 735, 741, 741, 735, 735, 740, 734, 735, 742, 741, 741, 741, 735, 741, 741, 735, 742, 741, 741, 741, 742, 734]}
# 0    378.14
# 1    778.32
# 2    752.64
# dtype: float64

# %%
data_milk_ = read_data()
pd.DataFrame(data_milk_).mean()
# Out:
# 0    380.26
# 1    782.78
# 2    791.08
# dtype: float64

# %%
data_milk_ = read_data()
pd.DataFrame(data_milk_).mean()
# Out:
# 0    381.00
# 1    780.30
# 2    767.92
# dtype: float64

# %%
data_milk_ = read_data()
pd.DataFrame(data_milk_).mean()
# Out:
# 0    381.70
# 1    779.18
# 2    761.68
# dtype: float64

# %%
data_coffee_ = read_data()
pd.DataFrame(data_coffee_).mean()
# Out:
# 0    382.26
# 1    778.12
# 2    757.92
# dtype: float64

# %%
data_coffee_ = read_data()
pd.DataFrame(data_coffee_).mean()
# Out:
# 0    383.96
# 1    781.96
# 2    783.44
# dtype: float64

# %%
test_ = read_data()
pd.DataFrame( test_ ).mean()
# Out:
# 0    384.06
# 1    782.92
# 2    790.74
# dtype: float64

# %% [markdown]
# ## Merge everything into one dataframe

# %%
df_main = {
  time_ + "_" +"water_tap" : pd.DataFrame(data_water_tap_).mean() ,
  time_ + "_" +"water_sm" : pd.DataFrame(data_water_sm_).mean() ,
  time_ + "_" +"apple" : pd.DataFrame(data_apple_).mean() ,
  time_ + "_" +"milk" : pd.DataFrame(data_milk_).mean() ,
  #time_ + "_" +"coffee" : pd.DataFrame(data_coffee_).mean()     
}

df = pd.DataFrame( df_main )

# %%
# Transpose the DataFrame
df_transposed = df.T
df_transposed.columns = [f'sensor_{i}' for i in range(df_transposed.shape[1])] # Rename columns for clarity
df_transposed
# Out:
#                            sensor_0  sensor_1  sensor_2
# 20250803_141027_water_tap    370.74    781.38    788.82
# 20250803_141027_water_sm     376.50    779.62    767.84
# 20250803_141027_apple        378.14    778.32    752.64
# 20250803_141027_milk         381.70    779.18    761.68

# %%
# Perform PCA on the transposed DataFrame
# For demonstration, we'll reduce to 2 components for plotting
pca = PCA(n_components=2)
principal_components_transposed = pca.fit_transform(df_transposed)

# %%
# Create a DataFrame for the principal components
pca_df_transposed = pd.DataFrame(data=principal_components_transposed,
                                 columns=['Principal Component 1', 'Principal Component 2'],
                                index = df_transposed.index)

# Print the explained variance ratio
print("\nExplained variance ratio for each component (on transposed data):")
print(pca.explained_variance_ratio_)
# Out:
# Explained variance ratio for each component (on transposed data):
# [0.97809156 0.02190831]

# %%
pca_df_transposed
# Out:
#                            Principal Component 1  Principal Component 2
# 20250803_141027_water_tap              21.982602              -0.601464
# 20250803_141027_water_sm                0.158219              -0.238419
# 20250803_141027_apple                 -15.027832              -2.430061
# 20250803_141027_milk                   -7.112989               3.269944

# %%
# Plotting the PCA results

plt.figure(figsize=(8, 6))
plt.scatter(pca_df_transposed['Principal Component 1'], pca_df_transposed['Principal Component 2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Transposed DataFrame')
plt.grid(True)
plt.savefig('pca_transposed_plot.png')
print("PCA plot of transposed DataFrame saved as pca_transposed_plot.png")


# Add labels to each point
for i, label in enumerate(pca_df_transposed.index):
    plt.annotate(label,                 # The text label
                 (pca_df_transposed['Principal Component 1'][i], # X-coordinate
                  pca_df_transposed['Principal Component 2'][i]),# Y-coordinate
                 textcoords="offset points", # How to position the text
                 xytext=(5,5),             # Distance from the point (x,y)
                 ha='left',                # Horizontal alignment
                 va='bottom')              # Vertical alignment
# Out:
# PCA plot of transposed DataFrame saved as pca_transposed_plot.png
# /tmp/ipykernel_15713/1662187912.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   (pca_df_transposed['Principal Component 1'][i], # X-coordinate
# /tmp/ipykernel_15713/1662187912.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pca_df_transposed['Principal Component 2'][i]),# Y-coordinate

# %%
# Display the DataFrame with principal components
print("\nDataFrame with Principal Components (on transposed data):")
print(pca_df_transposed)
# Out:
# DataFrame with Principal Components (on transposed data):
#                            Principal Component 1  Principal Component 2
# 20250803_141027_water_tap              18.664820              -5.545636
# 20250803_141027_water_sm               -2.877737              -2.030835
# 20250803_141027_apple                 -18.220112              -1.997889
# 20250803_141027_milk                   -9.566186               2.486505
# 20250803_141027_coffee                 11.999215               7.087855

# %% [markdown]
# ## Saving the new data to the pickle file

# %%
data_stored.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 data_stored.keys()
#
# NameError: name 'data_stored' is not defined

# %%
data_new = {
  time_ + "_" +"water_tap" : data_water_tap_ ,
  time_ + "_" +"water_sm" : data_water_sm_ ,
  time_ + "_" +"apple" : data_apple_ ,
  time_ + "_" +"milk" : data_milk_ ,
  time_ + "_" +"coffee" : data_coffee_     
}

# %%
data_stored = data_stored | data_new
data_stored.keys()

# %%
# add new data
store_data = True
if store_data == True:
   with open( db_name , 'wb') as f:
       pickle.dump( data_stored , f)

# %%
# check if previous measurements were made
db_name = "data.pickle"
if os.path.exists( db_name ):
    print("loading previous data")
    with open( db_name , "rb" ) as f:
        data_stored = pickle.load( f )
else:
    print("making new database")
    data_stored = {}

# %%
data_stored.items()
